# %%
class MathUtils:

    @staticmethod
    def average(a, b):
        return (a + b) / 2

print(MathUtils.average(2, 1))
# Out:
# 1.5

# %%
import itertools as it

# %%
import itertools as it
class Solution(object):
    def threeSum(self, nums):
        #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
        #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
        #list[list[int]]
        #result = list()
        print(result)
        sorted_result = [[]]
        for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
            if sorted(el) not in sorted_result:
                result.append(list(el))
                sorted_result.append(sorted(el))
                
        return(result)
       
        
sol = Solution()
sol.threeSum([-1, 0, 1, 2, -1, -4])

#print(sorted((4,3,5)))
# Out:
# []
# [[-1, 0, 1], [-1, 2, -1]]

# %%
#Scraping data from the web
import requests
from bs4 import BeautifulSoup
import lxml

# %%
r = requests.get("https://public.tableau.com/profile/upen.bendre#!/")
soup = BeautifulSoup(r.content, "lxml")
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <!--[if IEMobile 7]><html class="no-js ie iem7" lang="en" dir="ltr"><![endif]--><!--[if lte IE 6]><html class="no-js ie lt-ie9 lt-ie8 lt-ie7" lang="en" dir="ltr"><![endif]--><!--[if (IE 7)&(!IEMobile)]><html class="no-js ie lt-ie9 lt-ie8" lang="en" dir="ltr"><![endif]--><!--[if IE 8]><html class="no-js ie lt-ie9" id="ng-app" ng-app="vizhub" ng-csp lang="en" dir="ltr"><![endif]--><!--[if IE 9]><html class="no-js ie ie9 lte-ie9" id="ng-app" ng-app="vizhub" ng-csp lang="en" dir="ltr"><![endif]--><!--[if (gte IE 9)|(gt IEMobile 7)]><html class="no-js ie" id="ng-app" ng-app="vizhub" ng-csp lang="en" dir="ltr" prefix="fb: http://ogp.me/ns/fb# og: http://ogp.me/ns# article: http://ogp.me/ns/article# book: http://ogp.me/ns/book# profile: http://ogp.me/ns/profile# video: http://ogp.me/ns/video#"><![endif]--><!--[if !IE]><!--><html class="no-js" dir="ltr" id="ng-app" lang="en" ng-app="vizhub" ng-csp="" prefix="fb: http://ogp.me/ns/fb# og: http://ogp.me/ns# article: http://ogp.me/ns/article# book: http://ogp.me/ns/book# profile: http://ogp.me/ns/profile# video: http://ogp.me/ns/video#" xmlns:ng="http://angularjs.org"><!--<![endif]-->
# <head>
# <title ng-bind="(metaTag.title ? metaTag.title : 'Tableau Public' )">Tableau Public</title>
# <meta ng-attr-content="{{content}}" ng-attr-name="test-{{name}}" ng-repeat="(name, content) in testInfoService.values"/>
# <meta charset="utf-8"/><script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={xpid:"XA4CV19WGwUHU1dTAAM="};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{c.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(20),c={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(c.console=!0,o.indexOf("dev")!==-1&&(c.dev=!0),o.indexOf("nr_dev")!==-1&&(c.nrDev=!0))}catch(s){}c.nrDev&&i.on("internal-error",function(t){r(t.stack)}),c.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),c.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(c,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,c){try{h?h-=1:o(c||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,s.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:s.now();i("err",[t,n])}var i=t("handle"),a=t(21),c=t("ee"),s=t("loader"),f=t("gos"),u=window.onerror,d=!1,p="nr@seenError",h=0;s.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(l){"stack"in l&&(t(13),t(12),"addEventListener"in window&&t(6),s.xhrWrappable&&t(14),d=!0)}c.on("fn-start",function(t,e,n){d&&(h+=1)}),c.on("fn-err",function(t,e,n){d&&!n[p]&&(f(n,p,function(){return!0}),this.thrown=!0,o(n))}),c.on("fn-end",function(){d&&!this.thrown&&h>0&&(h-=1)}),c.on("internal-error",function(t){i("ierr",[t,s.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(){M++,S=y.hash,this[u]=b.now()}function o(){M--,y.hash!==S&&i(0,!0);var t=b.now();this[l]=~~this[l]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+y,e])}function a(t,e){t.on(e,function(){this[e]=b.now()})}var c="-start",s="-end",f="-body",u="fn"+c,d="fn"+s,p="cb"+c,h="cb"+s,l="jsTime",m="fetch",v="addEventListener",w=window,y=w.location,b=t("loader");if(w[v]&&b.xhrWrappable){var g=t(10),x=t(11),E=t(8),P=t(6),O=t(13),R=t(7),T=t(14),L=t(9),j=t("ee"),N=j.get("tracer");t(15),b.features.spa=!0;var S,M=0;j.on(u,r),j.on(p,r),j.on(d,o),j.on(h,o),j.buffer([u,d,"xhr-done","xhr-resolved"]),P.buffer([u]),O.buffer(["setTimeout"+s,"clearTimeout"+c,u]),T.buffer([u,"new-xhr","send-xhr"+c]),R.buffer([m+c,m+"-done",m+f+c,m+f+s]),E.buffer(["newURL"]),g.buffer([u]),x.buffer(["propagate",p,h,"executor-err","resolve"+c]),N.buffer([u,"no-"+u]),L.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(T,"send-xhr"+c),a(j,"xhr-resolved"),a(j,"xhr-done"),a(R,m+c),a(R,m+"-done"),a(L,"new-jsonp"),a(L,"jsonp-end"),a(L,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,!0),w[v]("load",i,!0),w[v]("popstate",function(){i(0,M>1)},!0)}},{}],5:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(13),c=t(12),s="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",p="resource",h="-start",l="-end",m="fn"+h,v="fn"+l,w="bstTimer",y="pushState",b=t("loader");b.features.stn=!0,t(8);var g=NREUM.o.EV;o.on(m,function(t,e){var n=t[0];n instanceof g&&(this.bstStart=b.now())}),o.on(v,function(t,e){var n=t[0];n instanceof g&&i("bst",[n,e,this.bstStart,b.now()])}),a.on(m,function(t,e,n){this.bstStart=b.now(),this.bstType=n}),a.on(v,function(t,e){i(w,[e,this.bstStart,b.now(),this.bstType])}),c.on(m,function(){this.bstStart=b.now()}),c.on(v,function(t,e){i(w,[e,this.bstStart,b.now(),"requestAnimationFrame"])}),o.on(y+h,function(t){this.time=b.now(),this.startPath=location.pathname+location.hash}),o.on(y+l,function(t){i("bstHist",[locati ...
# <link href="//ajax.googleapis.com" rel="dns-prefetch"/>
# <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
# <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# <link href="//publicstaticcdn.tableausoftware.com" rel="dns-prefetch"/>
# <link href="//publicstatic.tableausoftware.com" rel="dns-prefetch"/>
# <!--[if IE 9]>
# <link rel="prefetch" href="//ajax.googleapis.com" />
# <link rel="prefetch" href="//www.googletagmanager.com" />
# <link rel="prefetch" href="//www.google-analytics.com" />
# <link rel="prefetch" href="//publicstaticcdn.tableausoftware.com" />
# <link rel="prefetch" href="//publicstatic.tableausoftware.com" />
# <![endif]-->
# <meta content="!" name="fragment"/>
# <meta name="description" ng-attr-content="{{metaTag.description}}"/>
# <script>
#         var loc = window.location.href;
#         var dataLayer = window.dataLayer = window.dataLayer || [];
#         dataLayer.push({
#             'Application': 'Tableau Public',
#             'Realm': 'authors'
#         });
#       </script><meta name="robots" ng-attr-content='{{metaTag.indexable ? "index" : "noindex"}}'/>
# <link href="https://public.tableau.com/s/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <script>dataLayer = [{"language":"en","drupal.userStatus":"anonymous"}];</script>
# <link href="http://www.w3.org/1999/xhtml/vocab" rel="profile"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="width" name="MobileOptimized"/>
# <meta content="on" http-equiv="cleartype"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://public.tableau.com/s/sites/default/files/css/css_A3TX8WiTsExudIgwDfYMtIyjzbTgWvDqIgWpRP3D5fc.css" media="all" rel="stylesheet"/>
# <!--[if lte IE 8]>
# <link rel="stylesheet" href="https://public.tableau.com/s/sites/default/files/css/css_qoxFp8iZAV__BjgEQWLumAf2UpjHD10ZCeefhyR4SLk.css" media="all" />
# <![endif]-->
# <!--[if lt IE 9]>
#   <script src="//html5shiv.googlecode.com/svn/trunk/html5.js"></script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/es5-shim/4.1.0/es5-shim.min.js"></script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/respond.js/1.4.2/respond.min.js"></script>
#   <![endif]-->
# </head>
# <body class="html not-front not-logged-in page-profile page-profile-upenbendre author-profile i18n-en section-profile">
# <a class="element-invisible element-focusable" href="#main-content">Skip to main content</a>
# <!-- before top -->
# <!-- before page -->
# <div class="l-page has-no-sidebars">
# <header class="l-header at-top" role="banner">
# <div class="l-inner">
# <a data-test-id="headerNavbar-mobileHamburger" href="#" id="hamburger"><i class="icon-mobile-menu"></i></a>
# <div class="l-branding">
# <a class="site-logo" data-test-id="headerNavbar-home-link" href="/en-us/s/" rel="home">
# <img alt="Home" src="/s/sites/all/themes/revizit/logo.png"/>
# </a>
# </div>
# <div class="l-region l-region--navigation">
# <nav class="block block--menu-block block--menu-block-1" id="block-menu-block-1" role="navigation">
# <div class="menu-block-wrapper menu-block-1 menu-name-main-menu parent-mlid-0 menu-level-1">
# <ul class="menu"><li class="first leaf menu-mlid-217"><a class="gallery" data-test-id="headerNavbar-gallery-link" href="https://public.tableau.com/en-us/s/gallery">Gallery</a></li>
# <li class="leaf menu-mlid-502"><a class="authors" data-test-id="headerNavbar-authors-link" href="/en-us/s/authors">Authors</a></li>
# <li class="leaf menu-mlid-338"><a class="blog" data-test-id="headerNavbar-blog-link" href="/en-us/s/blog">Blog</a></li>
# <li class="leaf menu-mlid-385"><a class="resource" data-test-id="headerNavbar-resources-link" href="/en-us/s/resources">Resources</a></li>
# <li class="leaf menu-mlid-789 nav__activity"><a class="nav--activity" data-test-id="headerNavbar-activity-link" href="/en-us/s/activity">Activity</a></li>
# <li class="last leaf menu-mlid-387"><a class="login-link" data-test-id="headerNavbar-signIn-link" href="http://#">Sign In</a></li>
# </ul></div>
# </nav>
# <div aria-haspopup="true" class="block block--public-sitewide-ui block--public-sitewide-ui-author-profile-dropdown l-login" id="block-public-sitewide-ui-author-profile-dropdown">
# <div class="block__content">
# <div class="l-avatar" ng-show="loginService.loginRetreived">
# <img class="author-avatar" data-test-id="headerNavbar-authorAvatar" src=""/>
# <nav class="author-menu" data-test-id="headerNavbar-authorDropdownMenu">
# <a class="workspace-link" data-test-id="headerNavbar-myProfile-link" href="#">My Profile</a>
# <a class="profile-settings" data-test-id="headerNavbar-settings-link" href="#">Settings</a>
# <a class="product-download" data-test-id="headerNavbar-downloadApp-link" href="/en-us/s/download">Download the App</a>
# <a class="login-sign-out" data-test-id="headerNavbar-signOut-link" href="#" ng-click="sharedProfileUxStateService.logout()">Sign Out</a>
# <div class="app-usage" data-test-id="headerNavbar-spaceUsed">
# <span class="used">xxMB</span> of <span class="limit">10GB</span> used
#       <span class="indicator"><b class="progress"></b></span>
# </div>
# </nav>
# </div>
# </div>
# </div>
# </div>
# <div class="l-region l-region--search">
# <div class="block block--public-sitewide-ui block--public-sitewide-ui-search-button l-search" id="block-public-sitewide-ui-search-button">
# <div class="block__content">
# <div class="search-button-container">
# <button class="search-button" data-test-id="headerNavbar-search-link">
# <i class="icon-search"></i>
# </button>
# </div>
# </div>
# </div>
# <div class="block block--public-sitewide-ui block--public-sitewide-ui-search-overlay" id="block-public-sitewide-ui-search-overlay">
# <div class="block__content">
# <div class="l-search-overlay" id="modal-search-overlay">
# <form class="search-overlay-form" id="search-overlay-form">
# <div class="search-overlay-input-field">
# <button class="search-button" data-test-id="searchOverlay-search-link">
# <i class="icon-search"></i>
# </button>
# <input class="form-text form-search" id="search-overlay-input" maxlength="128" name="search-overlay-input" placeholder="Search Tableau Public" size="15" title="Enter the terms you wish to search for." type="search" value=""/>
# </div>
# </form>
# </div> </div>
# </div>
# </div>
# </div>
# </header>
# <section class="l-admin">
# <div class="l-inner">
# </div>
# </section>
# <div class="canvas-content">
# <section class="l-main">
# <div class="l-content l-inner" role="main">
# <a id="main-content"></a>
# <div class="vizhub-view" ng-view=""></div> </div>
# </section>
# <footer class="l-footer" role="contentinfo">
# <div class="l-inner">
# <div class="l-region l-region--footer">
# <div class="block block--nodeblock block--nodeblock-7" id="block-nodeblock-7">
# <div class="block__content">
# <div class="node node--block internal-node node--full node--block--full clearfix" id="node-7" role="article">
# <div class="content">
# <div class="field--body">
# <div class="about">
# <a data-test-id="footerNavbar-tableauHome-link" href="http://www.tableau.com">
# <span class="defer-image-load" data-defer-alt="Tableau Software" data-defer-src="//cdns.tblsft.com/sites/default/files/media/tableau-logo-transparent-fff.png">
# <noscript><img alt="Tableau Software" src="//cdns.tblsft.com/sites/default/files/media/tableau-logo-transparent-fff.png"/></noscript>
# </span>
# </a>
# <p>© 2018 Tableau Software, Incorporated and its licensors.<br/>All Rights Reserved</p>
# </div>
# <div class="navigation">
# <nav class="footer-navigation">
# <h3 class="footer-navigation__heading">Products</h3>
# <a data-test-id="footerNavbar-productTableauDesktop-link" href="http://www.tableau.com/products/desktop" target="_blank">Tableau Desktop</a>
# <a data-test-id="footerNavbar-productTableauServer-link" href="http://www.tableau.com/products/server" target="_blank">Tableau Server</a>
# <a data-test-id="footerNavbar-productTableauOnline-link" href="http://www.tableau.com/products/online" target="_blank">Tableau Online</a>
# <a data-test-id="footerNavbar-productTableauPublic-link" href="/en-us/s/download">Tableau Public <span class="badge orange"><em>Free</em></span></a>
# <a data-test-id="footerNavbar-productTableauReader-link" href="http://www.tableau.com/products/reader" target="_blank">Tableau Reader   <span class="badge orange"><em>Free</em></span></a>
# </nav>
# <nav class="footer-navigation">
# <h3 class="footer-navigation__heading">Legal</h3>
# <a data-test-id="footerNavbar-legalPrivacyPolicy-link" href="https://www.tableau.com/privacy" target="_blank">Privacy Policy</a>
# <a data-test-id="footerNavbar-legalDataPolicy-link" href="/en-us/s/data-policy">Data Policy</a>
# <a data-test-id="footerNavbar-legalTermsOfService-link" href="http://www.tableau.com/tos" target="_blank">Terms of Service</a>
# <a data-test-id="footerNavbar-legalPatents-link" href="http://www.tableau.com/ip" target="_blank">Patents &amp; IP</a>
# </nav>
# <nav class="footer-navigation">
# <h3 class="footer-navigation__heading">About</h3>
# <a data-test-id="footerNavbar-aboutCurrenStatus-link" href="https://trust.tableau.com/status/tableau-public" target="_blank">Current Status</a>
# <a data-test-id="footerNavbar-aboutFAQ-link" href="/s/faq">FAQ</a>
# <a data-test-id="footerNavbar-aboutCareers-link" href="http://careers.tableau.com" target="_blank">Careers</a>
# <a data-test-id="footerNavbar-aboutContact-link" href="/en-us/s/contact-us">Contact Us</a>
# </nav>
# </div>
# <div class="social">
# <a class="twitter" data-test-id="footerNavbar-socialTwitter-link" href="https://www.twitter.com/tableaupublic" target="_blank"><i class="icon-social-twitter"></i></a>
# <a class="facebook" data-test-id="footerNavbar-socialFacebook-link" href="https://www.facebook.com/TableauPublic" target="_blank"><i class="icon-social-facebook"></i></a>
# <a class="linkedin" data-test-id="footerNavbar-socialLinkedIn-link" href="https://www.linkedin.com/company/tableau-software" target="_blank"><i class="icon-social-linkedin-negative"></i></a>
# <a class="gplus" data-test-id="footerNavbar-socialGooglePlus-link" href="https://plus.google.com/+tableausoftware" target="_blank"><i class="icon-social-gplus"></i></a>
# </div>
# <style>
# #workbookEditForm .tile.embed { display:none; }
# #workbookEditForm #viz-embed-code { display:none; }
# .gss-result .gss-info { display:none; }
#
# .l-overview .page-title {
#   display: inline-block;
# }
# .l-overview .page-title__desc {
#   display: inline-block;
#   margin-bottom: 0;
# }
# .l-overview .page-title__desc + .sub-title {
#   display: block;
# }
# </style> </div>
# </div>
# </div>
# </div>
# </div>
# <div class="block block--locale block--locale-language" id="block-locale-language" role="complementary">
# <div class="block__content">
# <div aria-haspopup="true" class="global-footer__language" data-test-id="footerNavbar-languageSelector"><a class="anchor-link" id="lang-dropdown"></a><span class="selected">English</span><ul class="language-switcher-locale-url global-footer__language-options"><li class="zh-hans first"><a class="language-link" data-language-prefix="zh-cn" href="https://public.tableau.com/profile/upen.bendre" xml:lang="zh-hans">简体中文</a></li>
# <li class="en active"><a class="language-link active" data-language-prefix="en-us" href="https://public.tableau.com/profile/upen.bendre" xml:lang="en">English</a></li>
# <li class="fr"><a class="language-link" data-language-prefix="fr-fr" href="https://public.tableau.com/profile/upen.bendre" xml:lang="fr">Français</a></li>
# <li class="de"><a class="language-link" data-language-prefix="de-de" href="https://public.tableau.com/profile/upen.bendre" xml:lang="de">Deutsch</a></li>
# <li class="ja"><a class="language-link" data-language-prefix="ja-jp" href="https://public.tableau.com/profile/upen.bendre" xml:lang="ja">日本語</a></li>
# <li class="ko"><a class="language-link" data-language-prefix="ko-kr" href="https://public.tableau.com/profile/upen.bendre" xml:lang="ko">한국어</a></li>
# <li class="pt-br"><a class="language-link" data-language-prefix="pt-br" href="https://public.tableau.com/profile/upen.bendre" xml:lang="pt-br">Português</a></li>
# <li class="es last"><a class="language-link" data-language-prefix="es-es" href="https://public.tableau.com/profile/upen.bendre" xml:lang="es">Español</a></li>
# </ul></div> </div>
# </div>
# <div class="block block--public-sitewide-ui block--public-sitewide-ui-modal-signin" id="block-public-sitewide-ui-modal-signin">
# <div class="block__content">
# <div class="modal-tableau-dialogs is-hidden">
# <section aria-hidden="true" aria-labelledby="modal-label" class="form-server-login modal-login" data-test-id="signinModal" id="modal-server-login" role="dialog" tabindex="-1">
# <img class="logo-login" src="/s/sites/all/themes/revizit/images/public-logo-transparent-666.png"/>
# <div class="modal-inner">
# <div class="modal-content">
# <form action="/auth?destination=/" id="login-form" method="post">
# <div class="modal-login__subheading-container" data-test-id="siginModal-subheading">
# <!-- This div is to hold error messages in login modal like "Please activate your account..." -->
# </div>
# <div class="form-section">
# <div class="form-field">
# <label class="form-field__label" for="username">Email</label>
# <input class="input-text" data-test-id="signinModal-email-input" id="login-email" name="login-email" placeholder="Email" type="email"/>
# </div>
# </div>
# <div class="form-section form-password">
# <div class="form-field">
# <label class="form-field__label" for="password">Password</label>
# <input class="input-text" data-test-id="signinModal-password-input" id="login-password" name="login-password" placeholder="Password" type="password"/>
# </div>
# </div>
# <div class="keep-me-signed-in-section">
# <input data-test-id="signinModal-keepMeSignedIn-input" id="keep-me-signed-in" type="checkbox"/>
# <label for="keep-me-signed-in">Keep me signed in</label>
# </div>
# <div class="error-section" data-test-id="signinModal-error-section">
# </div>
# <div class="form-actions">
# <input class="action tile tile--l" data-test-id="signinModal-submit-button" id="submit" type="submit" value="Sign In"/>
# <div class="form-actions-footer">
# <a class="password-remind instruction" data-test-id="signinModal-forgotPassword-link" href="#">Forgot your password?</a>
# </div>
# </div>
# </form>
# </div>
# <footer class="login-additional">
#         Don't have a profile yet?<br/>
# <strong><a data-test-id="signinModal-signup-link" href="/en-us/auth/signup" id="account-signup">Create one now for free</a></strong>
# </footer>
# </div>
# </section>
# </div>
# </div>
# </div>
# <div class="block block--public-sitewide-ui block--public-sitewide-ui-modal-signup" id="block-public-sitewide-ui-modal-signup">
# <div class="block__content">
# <div class="modal-tableau-dialogs is-hidden">
# <section aria-hidden="true" aria-labelledby="modal-label" class="account-signup modal-signup" data-test-id="signupModal" id="modal-account-signup" role="dialog" tabindex="-1">
# <h2>Create a Profile</h2>
# <div class="modal-inner">
# <form id="form--account-signup" method="post">
# <div class="form-section" data-test-id="signupModal-realName-section">
# <div class="form-field">
# <label class="form-field__label" for="signup-realname">Name</label>
# <input class="input-text" data-test-id="signupModal-realName-input" id="signup-realname" name="signup-realname" placeholder="Name" type="text"/>
# <span class="instruction">Real names are important to us and build a sense of community.</span>
# </div>
# </div>
# <div class="form-section form-signup-email" data-test-id="signupModal-email-section">
# <div class="form-field">
# <label class="form-field__label" for="signup-email">Email</label>
# <input class="input-text" data-test-id="signupModal-email-input" id="signup-email" name="signup-email" placeholder="Email" type="email"/>
# <span class="instruction">Use your email to sign in to Tableau Public. Nobody sees this but us. We promise <em><strong>never</strong></em> to rent, sell, or barter your personal information to anyone.</span>
# <label class="email-unavailable custom-error">This email is unavailable.</label>
# </div>
# </div>
# <div class="form-section" data-test-id="signupModal-password-section">
# <div class="form-field">
# <label class="form-field__label" for="signup-password">Password</label>
# <input class="input-text" data-test-id="signupModal-password-input" id="signup-password" name="signup-password" placeholder="Password" type="password"/>
# <span class="instruction">Must be a minimum of 6 characters.</span>
# </div>
# </div>
# <div class="form-section" data-test-id="signupModal-confirmPassword-section">
# <div class="form-field">
# <label class="form-field__label" for="signup-password-confirm">Confirm</label>
# <input class="input-text" data-test-id="signupModal-confirmPassword-input" id="signup-password-confirm" name="signup-password-confirm" placeholder="Confirm" type="password"/>
# </div>
# </div>
# <div class="form-section form-signup-legal" data-test-id="signupModal-acceptTOS-section">
# <label class="form-section__header">Review the Legal</label>
# <div class="form-field">
# <input data-test-id="signupModal-acceptTOS-input" id="signup-legal" name="signup-legal" type="checkbox"/>
# <label for="signup-legal">I've read and agree to the <a href="https://www.tableau.com/en-us/tos" target="_blank">Terms of Service</a></label>
# </div>
# </div>
# <div class="form-actions">
# <div class="form-submit">
# <input class="confirm tile" data-test-id="signupModal-submit-button" disabled="disabled" id="submit" type="submit" value="Create My Profile"/>
# </div>
# </div>
# </form>
# </div>
# <div class="form__feedback success" data-test-id="signupModal-submit-successMessage">Success! Check for an email in your inbox for the activation code.</div>
# <div class="form__feedback error" data-test-id="signupModal-submit-errorMessage">Something went wrong.</div>
# </section>
# </div>
# </div>
# </div>
# <div class="block block--public-sitewide-ui block--public-sitewide-ui-modal-user-settings" id="block-public-sitewide-ui-modal-user-settings">
# <div class="block__content">
# <div class="modal-tableau-dialogs is-hidden">
# <div class="adhoc-tabs user-settings" data-test-id="userSettingsModal" id="modal-user-settings">
# <div class="modal-nav-header">
# <h2>Settings</h2>
# <div class="tab-nav">
# <a class="tab" data-test-id="nav-defaults-tab" href="#settings-tab-1">
#           Defaults
#         </a>
# <a class="tab" data-test-id="nav-emailAndPassword-tab" href="#settings-tab-2">
#           Email &amp; Password
#         </a>
# <a class="tab" data-test-id="nav-profileURL-tab" href="#settings-tab-3">
#           Profile URL
#         </a>
# <a class="tab" data-test-id="nav-accountManagement-tab" href="#settings-tab-4">
#           Account Management
#         </a>
# </div>
# </div>
# <div class="modal-inner">
# <div class="tab-content" data-test-id="defaults-tab" id="settings-tab-1">
# <form action="" class="form-settings--default" id="default-settings-form" method="post">
# <fieldset class="form-section user-default-settings">
# <h3 class="for-section__head">Viz Toolbar</h3>
# <div class="form-type-checkbox" data-premium="canEditShowShareOptions">
# <input data-test-id="showShare-input" id="viz-show-share" name="viz-show-share" type="checkbox"/>
# <label for="viz-show-share">Show share controls</label>
# </div>
# <div class="form-type-checkbox" data-premium="canEditAllowDataAccess">
# <input data-test-id="showDownload-input" id="viz-show-download" name="viz-show-download" type="checkbox"/>
# <label for="viz-show-download">Allow viz data to be downloaded (workbook, crosstab, data)</label>
# </div>
# <div class="form-type-checkbox" data-premium="canEditShowWatermark">
# <input data-test-id="showTableauLogo-input" id="viz-show-tableau-logo" name="viz-show-tableau-logo" type="checkbox"/>
# <label for="viz-show-tableau-logo">Show Tableau Logo</label>
# </div>
# </fieldset>
# <fieldset class="form-section">
# <h3 class="for-section__head">When Saving...</h3>
# <input data-test-id="hideVizDefault-input" id="viz-hide-viz-default" name="viz-hide-viz-default" type="checkbox"/>
# <label for="viz-hide-viz-default">Set my vizzes to hidden. Note that this will not change the visibility of previously published vizzes.</label>
# </fieldset>
# <div class="form-actions">
# <button class="confirm tile" data-test-id="submit-button" type="submit">Save Changes</button>
# </div>
# </form>
# </div>
# <div class="tab-content" data-test-id="emailAndPassword-tab" id="settings-tab-2">
# <form action="" class="form-change-email-password" data-test-id="changeEmail-form" id="form--change-email" method="post">
# <h3 class="for-section__head">Email</h3>
# <fieldset class="form-section email-old">
# <div class="form-field">
# <label class="form-field__label" for="email-old">Current Email</label>
# <input class="input-text" data-test-id="currentEmail-input" id="email-old" name="email-old" placeholder="Current Email" size="26" type="email"/>
# </div>
# </fieldset>
# <fieldset class="form-section password-current">
# <div class="form-field">
# <label class="form-field__label" for="password-current">Current Password</label>
# <input class="input-text" data-test-id="currentPassword-input" id="password-current" name="password-current" placeholder="Current Password" size="26" type="password"/><br/>
# </div>
# </fieldset>
# <fieldset class="form-section email-new" data-test-id="newEmail-section">
# <div class="form-field">
# <label class="form-field__label" for="email-new">New Email</label>
# <input class="input-text" data-test-id="newEmail-input" id="email-new" name="email-new" placeholder="New Email" size="26" type="email"/>
# </div>
# </fieldset>
# <fieldset class="form-section email-new-confirm" data-test-id="newEmailConfirm-section">
# <div class="form-field">
# <label class="form-field__label" for="email-new-confirm">Confirm</label>
# <input class="input-text" data-test-id="newEmailConfirm-input" id="email-new-confirm" name="email-new-confirm" placeholder="Confirm" size="26" type="email"/>
# </div>
# </fieldset>
# <div class="form-actions">
# <input class="confirm tile" data-test-id="submit-button" type="submit" value="Change Email"/>
# </div>
# </form>
# <form action="" class="form-settings--password form-change-email-password" data-test-id="changePassword-form" id="password-update-form" method="post">
# <h3 class="for-section__head">Password</h3>
# <fieldset class="form-section password-old">
# <div class="form-field">
# <label class="form-field__label" for="old-password">Current Password</label>
# <input class="input-text" data-test-id="currentPassword-input" id="old-password" name="old-password" placeholder="Current Password" size="32" type="password"/><br/>
# <span class="instruction"><a class="password-remind" href="#">Forgot your password?</a></span>
# </div>
# </fieldset>
# <fieldset class="form-section password-new" data-test-id="newPassword-section">
# <div class="form-field">
# <label class="form-field__label" for="new-password">New Password</label>
# <input class="input-text" data-test-id="newPassword-input" id="new-password" name="new-password" placeholder="New Password" size="32" type="password"/><br/>
# <span class="instruction">Must be a minimum of 6 characters.</span>
# </div>
# </fieldset>
# <fieldset class="form-section password-confirm" data-test-id="newPasswordConfirm-section">
# <div class="form-field">
# <label class="form-field__label" for="new-password-confirm">Confirm</label>
# <input class="input-text" data-test-id="newPasswordConfirm-input" id="new-password-confirm" name="new-password-confirm" placeholder="Confirm" size="32" type="password"/>
# </div>
# </fieldset>
# <div class="form-actions">
# <input class="confirm tile" data-test-id="submit-button" type="submit" value="Change Password"/>
# </div>
# </form>
# </div>
# <div class="tab-content account-manage" data-test-id="profileURL-tab" id="settings-tab-3">
# <p>You can customize your profile URL. It must be between 4-64 characters and only use lowercase letters, numbers, and periods. So long as it's not taken, it's yours.</p>
# <form action="" class="form-settings--profile-url" id="form--profile-url" method="post">
# <fieldset class="form-section form-section--inline profile-url">
# <div class="form-field">
#               https://public.tableau.com/profile/
#               <a class="profile-url--current" data-test-id="currentProfileURL">current.profile.name</a>
# <input class="is-hidden" data-test-id="profileURL-input" id="profile-url" name="profile-url" size="20" type="text"/>
# <a class="tile tile--ui profile-url-edit" data-test-id="profileURL-edit-toggle" data-test-is-editing="false" href="#edit-profile-url"><i class="icon-edit-pencil"></i><span class="tile__text">Edit</span></a>
# </div>
# </fieldset>
# <div class="form-actions">
# <input class="confirm tile" data-test-id="submit-button" disabled="" type="submit" value="Change Profile URL"/>
# </div>
# </form>
# </div>
# <div class="tab-content account-manage" data-test-id="accountManagement-tab" id="settings-tab-4">
# <div class="form-section">
# <h3>Available Space</h3>
# <div class="app-usage grid-8">
# <span class="indicator"><b class="progress"></b></span>
# <span data-test-id="appDataUsage-span"><span class="used">xxMB</span> of <span class="limit">10GB</span> used</span>
# </div>
# </div>
# <div class="form-section account-sign-out-all">
# <h3>Sign Out of All Sessions</h3>
# <div class="grid-8">
# <span class="description">If you chose the 'Keep Me Signed In' option during Sign In, you may be Signed In to multiple devices or locations. You can Sign Out of all sessions here.</span>
# </div>
# <div class="grid-4 omega">
# <a class="tile" data-test-id="signOutAll-button" href="#">Sign Out of All Sessions</a>
# </div>
# <div class="grid-12 error-block"></div>
# </div>
# <div class="form-section">
# <h3>Delete Account</h3>
# <div class="account-delete clearfix">
# <div class="grid-8">
# <div class="account-delete__message">
# <span class="description">We think Public is better with you. But if you must go, we'll make it as painless as possible.</span>
# <strong class="warning-final">This means the immediate and permanent deletion of your profile data and vizzes. Any links/embeds will cease to work when you delete your account.</strong>
# </div>
# </div>
# <div class="grid-4 omega">
# <a class="attention tile account-delete" data-test-id="deleteAccount-button" href="#" tabindex="-1">
#                 Delete My Account
#               </a>
# <form class="account-delete-confirm" data-test-id="deleteAccountConfirm-form">
# <fieldset class="form-section account-delete-password">
# <div class="form-field">
# <label class="form-field__label" for="account-delete-password">Password</label>
# <input class="input-text" data-test-id="password-input" id="account-delete-password" name="account-delete-password" placeholder="Password" size="20" type="password"/>
# </div>
# </fieldset>
# <fieldset class="form-section account-delete-password-confirm">
# <div class="form-field">
# <label class="form-field__label" for="account-delete-password-confirm">Confirm</label>
# <input class="input-text" data-test-id="passwordConfirm-input" id="account-delete-password-confirm" name="account-delete-password-confirm" placeholder="Confirm" size="20" type="password"/>
# </div>
# </fieldset>
# <div class="form-actions">
# <input class="attention tile" data-test-id="submit-button" type="submit" value="Confirm Deletion"/>
# </div>
# </form>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="block block--public-sitewide-ui block--public-sitewide-ui-modal-password-recover" id="block-public-sitewide-ui-modal-password-recover">
# <div class="block__content">
# <div class="modal-tableau-dialogs is-hidden">
# <section aria-hidden="true" aria-labelledby="modal-label" class="password-recover" data-test-id="recoverPasswordModal" id="modal-password-recover" role="dialog" tabindex="-1">
# <h2>Password Reset</h2>
# <div class="modal-inner">
# <p>Enter the email associated with your account and we'll send you a link to reset your password.</p>
# <form id="form--password-recover" method="post">
# <div class="form-section">
# <div class="form-field">
# <label class="form-field__label" for="recover-email">Email</label>
# <input class="input-text" data-test-id="passwordRecoverModal-email-input" id="recover-email" name="recover-email" placeholder="Email" required="" type="email"/>
# </div>
# </div>
# <div class="form-actions">
# <input class="confirm tile" data-test-id="passwordRecoverModal-submit-button" id="submit" type="submit" value="Send Email"/>
# </div>
# </form>
# </div>
# </section>
# </div>
# </div>
# </div>
# <div class="block block--public-sitewide-ui block--public-sitewide-ui-modal-password-recover-confirm" id="block-public-sitewide-ui-modal-password-recover-confirm">
# <div class="block__content">
# <div class="modal-tableau-dialogs is-hidden">
# <section aria-hidden="true" aria-labelledby="modal-label" class="password-recover-set" data-test-id="recoverPasswordConfirmModal" id="modal-password-recover-set" role="dialog" tabindex="-1">
# <h2>Password Reset</h2>
# <div class="modal-inner">
# <form id="form--password-recover-set" method="post">
# <div class="form-section">
# <div class="form-field">
# <label class="form-field__label" for="recover-password">Password</label>
# <input class="input-text" data-test-id="recoverPasswordConfirmModal-password-input" id="recover-password" name="recover-password" placeholder="Password" required="" type="password"/>
# </div>
# </div>
# <div class="form-section form-recover-password-confirm">
# <div class="form-field">
# <label class="form-field__label" for="recover-password-confirm">Confirm</label>
# <input class="input-text" data-test-id="recoverPasswordConfirmModal-confirmPassword-input" id="recover-password-confirm" name="recover-password-confirm" placeholder="Confirm" type="password"/>
# </div>
# </div>
# <!-- This is to hold the reset password code to submit/validate reset password flow -->
# <div class="form-section form-recover-password-recover-code">
# <label for="recover-code">Recover code</label>
# <div class="form-field">
# <input data-test-id="recoverPasswordConfirmModal-recoverCode-input" id="recover-code" name="recover-code" type="text"/>
# </div>
# </div>
# <div class="form-actions">
# <input class="confirm tile" data-test-id="recoverPasswordConfirmModal-submit-button" id="submit" type="submit" value="Reset Password"/>
# </div>
# </form>
# </div>
# </section>
# </div>
# </div>
# </div>
# </div>
# </div>
# </footer>
# </div>
# </div>
# <div class="mobile-menu-mask" id="mobile-menu-mask"></div>
# <!-- before page_bottom -->
# <!-- after page_bottom -->
# <script>dataLayer.push({"event":"jqueryLoaded"});</script>
# <script>window.FrontendInfo = {"featureFlags":{"sample_feature":false,"site_search":true,"slim_toolbar":true}};</script>
# <script src="https://public.tableau.com/s/sites/all/libraries/vizhub/commons.d59f220acc525d0ce30a.js?v=p2dc81"></script>
# <script src="https://public.tableau.com/s/sites/all/libraries/vizhub/angularCommons.eaa194f0f2d5a0b1e935.js?v=p2dc81"></script>
# <script src="https://public.tableau.com/s/sites/all/libraries/vizhub/frontend.a0b28e16feac06d526d8.js?v=p2dc81"></script>
# <script>Drupal.settings.getLanguagePreferencePath = "/s/sites/all/modules/lang_dropdown_remind/lang_dropdown_remind.callback.php";</script>
# <script>jQuery.extend(Drupal.settings, {"basePath":"\/en-us\/s\/","pathPrefix":"en-us\/","colorbox":{"transition":"none","speed":"250","opacity":"1","slideshow":false,"slideshowAuto":true,"slideshowSpeed":"2500","slideshowStart":"start slideshow","slideshowStop":"stop slideshow","current":"{current} of {total}","previous":"\u00ab Prev","next":"Next \u00bb","close":"","overlayClose":true,"maxWidth":"98%","maxHeight":"98%","initialWidth":"750","initialHeight":"500","fixed":true,"scrolling":true,"mobiledetect":true,"mobiledevicewidth":"480px"},"gss":{"key":"014661568629943033057:ki3viiva-o4"},"deferImage":{"deferClass":"defer-image-load","deferTiming":"load"},"tabia":{"publicversion":"10.5","qthistory":"Drupal-quicktabs-active-tab-id-","facebookAppId":""},"tableauBrightcove":{"accountId":"3798483592001","defaultPlayerId":"default"},"lang_dropdown_remind":{"markup":"\u003Cdiv class=\u0022inner\u0022\u003E!message !close_button\u003C\/div\u003E","messages":{"default":"This page is available in your preferred language. Navigate there using \u003Ca id=\u0022trigger-langdropdown\u0022 href=\u0022#\u0022\u003Ethe language drop down menu\u003C\/a\u003E."},"close":{"default":"\u0026#10006;"},"repeat":0,"prependto":"#page"},"eloqua_api":{"trackingRemoteUrl":"https:\/\/img.en25.com\/i\/elqCfg.min.js","siteId":"840"}});</script>
# <!-- Google Tag Manager -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-WP98PN" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-WP98PN');</script>
# <!-- End Google Tag Manager --><script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"35f2b5d0eb","applicationID":"6776172","transactionName":"NAADMkcCCkVVAhYNXQ1KNBRcTEtfWgUHHBwTDRE=","queueTime":0,"applicationTime":27,"atts":"GEcARA8YGUs=","errorBeacon":"bam.nr-data.net","agent":""}</script></body>
# </html>
# >

# %%
links = soup.find_all("a", {"class":"language-link"})
for link in links:
    print(link.get("href"))
# Out:
# https://public.tableau.com/profile/upen.bendre
# https://public.tableau.com/profile/upen.bendre
# https://public.tableau.com/profile/upen.bendre
# https://public.tableau.com/profile/upen.bendre
# https://public.tableau.com/profile/upen.bendre
# https://public.tableau.com/profile/upen.bendre
# https://public.tableau.com/profile/upen.bendre
# https://public.tableau.com/profile/upen.bendre

# %%
# %history    #lists previous commands in the session. This is a Jupyter notebook magic command
# Out:
# class MathUtils:
#
#     @staticmethod
#     def average(a, b):
#         return a + b / 2
#
# print(MathUtils.average(2, 1))
# class MathUtils:
#
#     @staticmethod
#     def average(a, b):
#         return (a + b) / 2
#
# print(MathUtils.average(2, 1))
# import itertools
#
# class FileOwners:
#
#     @staticmethod
#     def group_by_owners(files):
#         return None
#
# files = {
#     'Input.txt': 'Randy',
#     'Code.py': 'Stan',
#     'Output.txt': 'Randy'
# }
# print(FileOwners.group_by_owners(files))
#
# def group_by_owners (dict a):
#     for key, value in
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         it.combinations(nums, 3)
# it.combinations([-1, 0, 1, 2, -1, -4], 3)
# print(it.combinations([-1, 0, 1, 2, -1, -4], 3))
# it.combinations([-1, 0, 1, 2, -1, -4], 3)
# yield(it.combinations([-1, 0, 1, 2, -1, -4], 3))
# it.combinations([-1, 0, 1, 2, -1, -4], 3)
# list(it.combinations([-1, 0, 1, 2, -1, -4], 3))
# class Solution(object):
#     def threeSum(self, nums):
#         comb = it.combinations(nums, 3)
# list(it.combinations([-1, 0, 1, 2, -1, -4], 3))
# [yield comb]
# list(it.combinations([-1, 0, 1, 2, -1, -4], 3))
# yield comb
# class Solution(object):
#     def threeSum(self, nums):
#         for elem in it.combinations(nums, 3):
#             yield type(elem)
#
# sol = Solution()
# print(sol.threeSum)
# class Solution(object):
#     def threeSum(self, nums):
#         for elem in it.combinations(nums, 3):
#             yield type(elem)
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         for elem in it.combinations(nums, 3):
#             print type(elem)
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         for elem in it.combinations(nums, 3):
#             print(type(elem))
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         for elem in it.combinations(nums, 3):
#             print(elem.fsum())
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         for elem in it.combinations(nums, 3):
#             map(map, elem)
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         for elem in it.combinations(nums, 3):
#             map(sum, elem)
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         for elem in it.combinations(nums, 3):
#             print(map(sum, elem))
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         for elem in it.combinations(nums, 3):
#             print(list(map(sum, elem))
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         for elem in it.combinations(nums, 3):
#             print(list(map(sum, elem)))
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         for elem in it.combinations(nums, 3):
#             print(elem)
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         for elem in it.combinations(nums, 3):
#             print(elem)
#             print(str(map(sum, elem))
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         for elem in it.combinations(nums, 3):
#             print(elem)
#             print(str(map(sum, elem)))
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         for elem in it.combinations(nums, 3):
#             print(elem)
#             print(int(map(sum, elem)))
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         for elem in it.combinations(nums, 3):
#             print(elem)
#             print(map(sum, elem))
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         for elem in it.combinations(nums, 3):
#             print(elem)
#             print(map(sum, elem) == 0)
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         #for elem in it.combinations(nums, 3):
#         #    print(elem)
#         print(map(sum, it.combinations(nums, 3)) == 0)
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         #for elem in it.combinations(nums, 3):
#         #    print(elem)
#         k = it.combinations(nums, 3)
#         print(list(k))
#         #print(map(sum, it.combinations(nums, 3)) == 0)
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         #for elem in it.combinations(nums, 3):
#         #    print(elem)
#         k = it.combinations(nums, 3)
#         #print(list(k))
#         list(map(sum, k))
#         #print(map(sum, it.combinations(nums, 3)) == 0)
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         #for elem in it.combinations(nums, 3):
#         #    print(elem)
#         k = it.combinations(nums, 3)
#         #print(list(k))
#         #list(map(sum, k))
#         #print(map(sum, it.combinations(nums, 3)) == 0)
#         l = [sum(elem) for elem in k]
#         print(l)
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         #for elem in it.combinations(nums, 3):
#         #    print(elem)
#         k = it.combinations(nums, 3)
#         #print(list(k))
#         #list(map(sum, k))
#         #print(map(sum, it.combinations(nums, 3)) == 0)
#         l = [sum(elem) for elem in it.combinations(nums, 3)]
#         print(l)
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         #for elem in it.combinations(nums, 3):
#         #    print(elem)
#         k = it.combinations(nums, 3)
#         #print(list(k))
#         #list(map(sum, k))
#         #print(map(sum, it.combinations(nums, 3)) == 0)
#         l = [sum(elem) for elem in it.combinations(nums, 3)]
#         print(it.ifilter(lambda x: x==0, l))
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         #for elem in it.combinations(nums, 3):
#         #    print(elem)
#         k = it.combinations(nums, 3)
#         #print(list(k))
#         #list(map(sum, k))
#         #print(map(sum, it.combinations(nums, 3)) == 0)
#         l = [sum(elem) for elem in it.combinations(nums, 3)]
#         print(it.filter(lambda x: x!=0, l))
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         #for elem in it.combinations(nums, 3):
#         #    print(elem)
#         k = it.combinations(nums, 3)
#         #print(list(k))
#         #list(map(sum, k))
#         #print(map(sum, it.combinations(nums, 3)) == 0)
#         l = [sum(elem) for elem in it.combinations(nums, 3)]
#         print(it.filter(lambda x: x > 0, l))
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         #for elem in it.combinations(nums, 3):
#         #    print(elem)
#         k = it.combinations(nums, 3)
#         #print(list(k))
#         #list(map(sum, k))
#         #print(map(sum, it.combinations(nums, 3)) == 0)
#         l = [sum(elem) for elem in it.combinations(nums, 3)]
#         print(it.filterfalse(lambda x: x > 0, l))
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         #for elem in it.combinations(nums, 3):
#         #    print(elem)
#         k = it.combinations(nums, 3)
#         #print(list(k))
#         #list(map(sum, k))
#         #print(map(sum, it.combinations(nums, 3)) == 0)
#         l = [sum(elem) for elem in it.combinations(nums, 3)]
#         print(list(it.filterfalse(lambda x: x > 0, l)))
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         #for elem in it.combinations(nums, 3):
#         #    print(elem)
#         k = it.combinations(nums, 3)
#         #print(list(k))
#         #list(map(sum, k))
#         #print(map(sum, it.combinations(nums, 3)) == 0)
#         l = [sum(elem) for elem in it.combinations(nums, 3)]
#         print(list(it.filterfalse(lambda x: x <> 0, l)))
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         #for elem in it.combinations(nums, 3):
#         #    print(elem)
#         k = it.combinations(nums, 3)
#         #print(list(k))
#         #list(map(sum, k))
#         #print(map(sum, it.combinations(nums, 3)) == 0)
#         l = [sum(elem) for elem in it.combinations(nums, 3)]
#         print(list(it.filterfalse(lambda x: x != 0, l)))
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         #for elem in it.combinations(nums, 3):
#         #    print(elem)
#         k = it.combinations(nums, 3)
#         #print(list(k))
#         #list(map(sum, k))
#         #print(map(sum, it.combinations(nums, 3)) == 0)
#         #l = [sum(elem) for elem in it.combinations(nums, 3)]
#         print(list(it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3))))
#         #[elem ]
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         #for elem in it.combinations(nums, 3):
#         #    print(elem)
#         k = it.combinations(nums, 3)
#         ans = list(it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         print(type(ans))
#         #[elem ]
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         #for elem in it.combinations(nums, 3):
#         #    print(elem)
#         k = it.combinations(nums, 3)
#         ans = list(it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         print(ans)
#         #[elem ]
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         #for elem in it.combinations(nums, 3):
#         #    print(elem)
#         k = it.combinations(nums, 3)
#         #ans = list(it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         list(it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         #print(ans)
#         #[elem ]
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         ans = list(it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         #list(it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         print(ans)
#         #[elem ]
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         ans = list(it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         #list(it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         print(ans)
#         print(map(list, ans))
#         #[elem ]
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         ans = list(it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         #list(it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         print(ans)
#         print(list(map(list, ans)))
#         #[elem ]
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         ans = it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3))
#         #list(it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         print(ans)
#         print(list(map(list, ans)))
#         #[elem ]
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# class Solution(object):
#     def threeSum(self, nums):
#         return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #[elem ]
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         result = list[list[int]]
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#             print(e1)
#
#
#
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         result = list(list[int])
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#             print(e1)
#
#
#
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         result = list(list(int)
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#             print(e1)
#
#
#
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         result = list(list(int))
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#             print(e1)
#
#
#
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         result = list[]
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#             print(e1)
#
#
#
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         list[list[int]] result
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#             print(e1)
#
#
#
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         list[list[int]]
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#             print(e1)
#
#
#
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         #list[list[int]]
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#             print(e1)
#
#
#
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         #list[list[int]]
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#             print(el)
#
#
#
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         #list[list[int]]
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#             print(el)
#
#
#
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# print(sort((4,3,5)))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         #list[list[int]]
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#             print(el)
#
#
#
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# print(sorted((4,3,5)))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         #list[list[int]]
#         result = [[int]]
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#             print(el)
#
#
#
#
# sol = Solution()
# print(sol.threeSum([-1, 0, 1, 2, -1, -4]))
# print(sorted((4,3,5)))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         #list[list[int]]
#         result = [[int]]
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#             print(sorted(el))
#
#
#
#
# sol = Solution()
# sol.threeSum([-1, 0, 1, 2, -1, -4])
# #print(sorted((4,3,5)))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         #list[list[int]]
#         result = [[int]]
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#
#             print(sorted(el))
#
#
#
#
# sol = Solution()
# sol.threeSum([-1, 0, 1, 2, -1, -4])
# print(k = find([-1, 0, 1, 2, -1, -4], 1))
# #print(sorted((4,3,5)))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         #list[list[int]]
#         result = [[int]]
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#
#             print(sorted(el))
#
#
#
#
# sol = Solution()
# sol.threeSum([-1, 0, 1, 2, -1, -4])
# k = find([-1, 0, 1, 2, -1, -4], 1)
# print(k)
# #print(sorted((4,3,5)))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         #list[list[int]]
#         result = [[int]]
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#
#             print(sorted(el))
#
#
#
#
# sol = Solution()
# sol.threeSum([-1, 0, 1, 2, -1, -4])
# k = 1 in [-1, 0, 1, 2, -1, -4]
# print(k)
# #print(sorted((4,3,5)))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         #list[list[int]]
#         result = [[int]]
#         sorted_result[[int]]
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#             if sorted(el) not in sorted_result:
#                 result.append(el)
#                 sorted_result.append(sorted(el))
#
#
#
#
# sol = Solution()
# sol.threeSum([-1, 0, 1, 2, -1, -4])
#
# #print(sorted((4,3,5)))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         #list[list[int]]
#         result = [[int]]
#         sorted_result = [[int]]
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#             if sorted(el) not in sorted_result:
#                 result.append(el)
#                 sorted_result.append(sorted(el))
#
#
#
#
# sol = Solution()
# sol.threeSum([-1, 0, 1, 2, -1, -4])
#
# #print(sorted((4,3,5)))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         #list[list[int]]
#         result = [[int]]
#         sorted_result = [[int]]
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#             if sorted(el) not in sorted_result:
#                 result.append(el)
#                 sorted_result.append(sorted(el))
#         return(result)
#
#
#
#
# sol = Solution()
# sol.threeSum([-1, 0, 1, 2, -1, -4])
#
# #print(sorted((4,3,5)))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         #list[list[int]]
#         result = [[]]
#         sorted_result = [[int]]
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#             if sorted(el) not in sorted_result:
#                 result.append(el)
#                 sorted_result.append(sorted(el))
#         return(result)
#
#
#
#
# sol = Solution()
# sol.threeSum([-1, 0, 1, 2, -1, -4])
#
# #print(sorted((4,3,5)))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         #list[list[int]]
#         result = [[]]
#         sorted_result = [[int]]
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#             if sorted(el) not in sorted_result:
#                 result.append(list(el))
#                 sorted_result.append(sorted(el))
#         return(result)
#
#
#
#
# sol = Solution()
# sol.threeSum([-1, 0, 1, 2, -1, -4])
#
# #print(sorted((4,3,5)))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         #list[list[int]]
#         result = [[]]
#         sorted_result = [[]]
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#             if sorted(el) not in sorted_result:
#                 result.append(list(el))
#                 sorted_result.append(sorted(el))
#         return(result)
#
#
#
#
# sol = Solution()
# sol.threeSum([-1, 0, 1, 2, -1, -4])
#
# #print(sorted((4,3,5)))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         #list[list[int]]
#         result = [[]]
#         sorted_result = [[]]
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#             if sorted(el) not in sorted_result:
#                 result.append(list(el))
#                 sorted_result.append(sorted(el))
#         result.drop(0)
#         return(result)
#
#
#
#
# sol = Solution()
# sol.threeSum([-1, 0, 1, 2, -1, -4])
#
# #print(sorted((4,3,5)))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         #list[list[int]]
#         result = [[]]
#         sorted_result = [[]]
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#             if sorted(el) not in sorted_result:
#                 result.append(list(el))
#                 sorted_result.append(sorted(el))
#
#         return(result.pop(0))
#
#
#
#
# sol = Solution()
# sol.threeSum([-1, 0, 1, 2, -1, -4])
#
# #print(sorted((4,3,5)))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         #list[list[int]]
#         result = [[]]
#         sorted_result = [[]]
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#             if sorted(el) not in sorted_result:
#                 result.append(list(el))
#                 sorted_result.append(sorted(el))
#
#         return(result[1:])
#
#
#
#
# sol = Solution()
# sol.threeSum([-1, 0, 1, 2, -1, -4])
#
# #print(sorted((4,3,5)))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         #list[list[int]]
#         result = [[]]
#         print result
#         sorted_result = [[]]
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#             if sorted(el) not in sorted_result:
#                 result.append(list(el))
#                 sorted_result.append(sorted(el))
#
#         return(result[1:])
#
#
#
#
# sol = Solution()
# sol.threeSum([-1, 0, 1, 2, -1, -4])
#
# #print(sorted((4,3,5)))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         #list[list[int]]
#         result = [[]]
#         print(result)
#         sorted_result = [[]]
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#             if sorted(el) not in sorted_result:
#                 result.append(list(el))
#                 sorted_result.append(sorted(el))
#
#         return(result[1:])
#
#
#
#
# sol = Solution()
# sol.threeSum([-1, 0, 1, 2, -1, -4])
#
# #print(sorted((4,3,5)))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         #list[list[int]]
#         result = list[list]
#         print(result)
#         sorted_result = [[]]
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#             if sorted(el) not in sorted_result:
#                 result.append(list(el))
#                 sorted_result.append(sorted(el))
#
#         return(result[1:])
#
#
#
#
# sol = Solution()
# sol.threeSum([-1, 0, 1, 2, -1, -4])
#
# #print(sorted((4,3,5)))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         #list[list[int]]
#         result = list[list[]]
#         print(result)
#         sorted_result = [[]]
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#             if sorted(el) not in sorted_result:
#                 result.append(list(el))
#                 sorted_result.append(sorted(el))
#
#         return(result[1:])
#
#
#
#
# sol = Solution()
# sol.threeSum([-1, 0, 1, 2, -1, -4])
#
# #print(sorted((4,3,5)))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         #list[list[int]]
#         result = list[list[int]]
#         print(result)
#         sorted_result = [[]]
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#             if sorted(el) not in sorted_result:
#                 result.append(list(el))
#                 sorted_result.append(sorted(el))
#
#         return(result[1:])
#
#
#
#
# sol = Solution()
# sol.threeSum([-1, 0, 1, 2, -1, -4])
#
# #print(sorted((4,3,5)))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         #list[list[int]]
#         result = list()
#         print(result)
#         sorted_result = [[]]
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#             if sorted(el) not in sorted_result:
#                 result.append(list(el))
#                 sorted_result.append(sorted(el))
#
#         return(result[1:])
#
#
#
#
# sol = Solution()
# sol.threeSum([-1, 0, 1, 2, -1, -4])
#
# #print(sorted((4,3,5)))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         #list[list[int]]
#         result = list(list())
#         print(result)
#         sorted_result = [[]]
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#             if sorted(el) not in sorted_result:
#                 result.append(list(el))
#                 sorted_result.append(sorted(el))
#
#         return(result[1:])
#
#
#
#
# sol = Solution()
# sol.threeSum([-1, 0, 1, 2, -1, -4])
#
# #print(sorted((4,3,5)))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         #list[list[int]]
#         result = [[]]
#         print(result)
#         sorted_result = [[]]
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#             if sorted(el) not in sorted_result:
#                 result.append(list(el))
#                 sorted_result.append(sorted(el))
#
#         return(result[1:])
#
#
#
#
# sol = Solution()
# sol.threeSum([-1, 0, 1, 2, -1, -4])
#
# #print(sorted((4,3,5)))
# import itertools as it
# class Solution(object):
#     def threeSum(self, nums):
#         #return (list(map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))))
#         #full = map(list, it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)))
#         #list[list[int]]
#         result = list()
#         print(result)
#         sorted_result = [[]]
#         for el in it.filterfalse(lambda elem: sum(elem) != 0, it.combinations(nums, 3)):
#             if sorted(el) not in sorted_result:
#                 result.append(list(el))
#                 sorted_result.append(sorted(el))
#
#         return(result)
#
#
#
#
# sol = Solution()
# sol.threeSum([-1, 0, 1, 2, -1, -4])
#
# #print(sorted((4,3,5)))
# import requests
# from bs4 import BeautifulSoup
# r = requests.get("https://www.amazon.in/mobile-phones/b/ref=nav_shopall_sbc_mobcomp_all_mobiles?ie=UTF8&node=1389401031")
# BeautifulSoup(r.content).prettify
# r = requests.get("https://www.amazon.in/mobile-phones/b/ref=nav_shopall_sbc_mobcomp_all_mobiles?ie=UTF8&node=1389401031")
# print(BeautifulSoup(r.content).prettify)
# body_tag = soup.body
# body_tag.descendants
# r = requests.get("https://www.amazon.in/mobile-phones/b/ref=nav_shopall_sbc_mobcomp_all_mobiles?ie=UTF8&node=1389401031")
# soup = r.content
# print(BeautifulSoup(soup).prettify)
# body_tag = soup.body
# body_tag.descendants
# body = soup.find_all("body")
# body = soup.findall("body")
# r = requests.get("https://www.amazon.in/mobile-phones/b/ref=nav_shopall_sbc_mobcomp_all_mobiles?ie=UTF8&node=1389401031")
# soup = BeautifulSoup(r.content)
# print(soup.prettify)
# body = soup.findall("body")
# body = soup.find_all("body")
# for item in body:
#     print item
# for item in body:
#     print(item)
# for item in body.descendants:
#     print(item)
# #body = soup.find_all("body")
# body_tag = soup.body_tag
# #body = soup.find_all("body")
# del body_tag
# body = soup.body_tag
# #body = soup.find_all("body")
#
# body = soup.body_tag
# for item in body.descendants:
#     print(item)
# print(body.contents)
# print(body)
# body = soup.find_all("body")
# for item in body:
#     print(item)
# print(soup.descendants)
# print(list(soup.descendants))
# for elem in soup.descendants:
#     print(elem)
# for elem in soup.descendants:
#     elem.contents[0]
# for elem in soup.descendants:
#     print(elem.find_all_next)
# for elem in soup.descendants:
#     print(elem.find_all_next)
#     print("----------------------------")
# r = requests.get("https://www.amazon.in/mobile-phones/b/ref=nav_shopall_sbc_mobcomp_all_mobiles?ie=UTF8&node=1389401031")
# soup = BeautifulSoup(r.content, lxml)
# print(soup.prettify)
# #Scraping data from the web
# import requests
# from bs4 import BeautifulSoup
# import lxml
# r = requests.get("https://www.amazon.in/mobile-phones/b/ref=nav_shopall_sbc_mobcomp_all_mobiles?ie=UTF8&node=1389401031")
# soup = BeautifulSoup(r.content, lxml)
# print(soup.prettify)
# r = requests.get("https://www.amazon.in/mobile-phones/b/ref=nav_shopall_sbc_mobcomp_all_mobiles?ie=UTF8&node=1389401031")
# soup = BeautifulSoup(r.content)
# print(soup.prettify)
# r = requests.get("https://public.tableau.com/profile/upen.bendre#!/")
# soup = BeautifulSoup(r.content)
# print(soup.prettify)
# links = soup.find_all("a")
# for link in links.get("href"):
#     print(link)
# links = soup.find_all("a")
# for link in links:
#     if "http" in link.get("href"):
#         print(link)
# links = soup.find_all("a")
# for link in links:
#     if "http" in link.get("href"):
#         print(link.text)
# links = soup.find_all("a")
# for link in links:
#     if "#!" in link.get("href"):
#         print(link.text)
# links = soup.find_all("a")
# for link in links:
#     if "htto" in link.get("href"):
#         print(link.text)
# links = soup.find_all("a")
# for link in links:
#     if "http" in link.get("href"):
#         print(link.text)
# links = soup.find_all("a")
# for link in links:
#     #if "http" in link.get("href"):
#     print(link.text)
# r = requests.get("https://public.tableau.com/profile/upen.bendre#!/")
# soup = BeautifulSoup(r.content, "lxml")
# print(soup.prettify)
# links = soup.find_all("a")
# for link in links:
#     if "https" in link.get("href"):
#     print(link.text)
# links = soup.find_all("a")
# for link in links:
#     if "https" in link.get("href"):
#         print(link.text)
# links = soup.find_all("a", {"class":"language-link"})
# for link in links:
#     print(link.text)
# links = soup.find_all("a", {"class":"language-link"})
# for link in links:
#     print(link.contents)
# links = soup.find_all("a", {"class":"language-link"})
# for link in links:
#     print(link.get("href"))
# %history
# type(%history)
# %history
